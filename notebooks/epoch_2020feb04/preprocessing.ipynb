# %%
# julia imports
using CCDReduction
using ProgressLogging
using PyCall
using PyPlot
using SiriusB
using Statistics

# %%
# python imports
hp = pyimport("hciplot")
fits = pyimport("astropy.io.fits")
plt = pyimport("matplotlib.pyplot")

## matplotlib params

# %%
data = fits.getdata(datadir("2020nov28_sirius-b_cube.fits"));

# %%
hp.plot_frames(data[1, :, :], cmap="inferno")
# Out:
# Figure(PyObject <Figure size 600x600 with 2 Axes>)
